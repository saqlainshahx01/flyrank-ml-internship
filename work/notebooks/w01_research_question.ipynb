# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saqlainshahx01/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/saqlainshahx01/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 122 (delta 36), reused 95 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (122/122), 1.84 MiB | 15.23 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/flyrank-ml-internship/flyrank-ml-internship

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# I'm choosing this lane because I've already worked with the starter dataset in Notebooks 01 and 02, and the results there showed a clear, measurable gap between a simple hand rule and a learned model. This lane also has one of the deepest data foundations in the warehouse, and it maps directly to a real business action — deciding which pages a content team should review first — rather than a purely academic exercise.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Decision this improves: Which pages should a content team review first, out of thousands, when they only have capacity to act on a small number each week?

# Unit of analysis: One content page (content_id), scored using its trailing 90-day performance signals.

# Action someone takes: A reviewer opens the top-ranked pages from the queue and decides whether to refresh, expand, protect, or prune each one.

# Cost of a wrong recommendation: If a page is wrongly flagged as high-priority, the team wastes limited review time on a page that didn't need it, while a genuinely declining page gets missed. Since this is a decision-support ranking, the real risk is wasted attention, not direct harm.

# Why ML can help: A hand-written baseline rule only reaches about 24% precision on its top-50 picks. A learned model can combine many weak signals (position, CTR, freshness, engagement) in ways a fixed rule can't — the starter run already showed a random forest roughly tripling that precision.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Below are 2-3 real numbers from the starter dataset that show why this lane is worth pursuing.
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("Total rows:", len(df))
print("Rows with impressions > 0 and age >= 90 days:",
      len(df[(df["impressions_90d"] > 0) & (df["content_age_days"] >= 90)]))
print("Share currently marked as declining:",
      round((df["trend_direction"] == "down").mean() * 100, 1), "%")
# Out:
# Total rows: 30000
# Rows with impressions > 0 and age >= 90 days: 30000
# Share currently marked as declining: 54.2 %

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# What I can say: This work will produce observed, evidence-based rankings — pages that show measurable patterns of decline, low engagement, or under-performing CTR relative to their position tier. Claims will be directional ("pages with X pattern are more likely to show Y") and framed as decision-support: a ranked list to help a reviewer prioritize limited time, not an automated fix.

# What I cannot claim: This is not causal proof — I cannot say a refresh WILL cause recovery, since that requires an actual experiment, not observational data. I also cannot claim to have discovered a Google ranking algorithm factor, or that I am predicting AI search visibility. Any product-level scores (like health_score) are treated as background context, never as ground truth or as a model feature.
